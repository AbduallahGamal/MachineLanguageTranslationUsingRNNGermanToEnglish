# %% [markdown]
# <a href="https://colab.research.google.com/github/AbduallahGamal/MachineLanguageTranslationUsingRNNGermanToEnglish/blob/main/MachineLanguageTranslationUsingRNNGermanToEnglish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			line = normalize('NFD', line).encode('ascii', 'ignore')
			line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
			line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'deu.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, '/content/english-german.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: /content/english-german.pkl
# [go] => [geh]
# [hi] => [hallo]
# [hi] => [gru gott]
# [run] => [lauf]
# [run] => [lauf]
# [wow] => [potzdonner]
# [wow] => [donnerwetter]
# [duck] => [kopf runter]
# [fire] => [feuer]
# [help] => [hilfe]
# [help] => [zu hulf]
# [stay] => [bleib]
# [stop] => [stopp]
# [stop] => [anhalten]
# [wait] => [warte]
# [wait] => [warte]
# [begin] => [fang an]
# [do it] => [mache es]
# [do it] => [tue es]
# [go on] => [mach weiter]
# [hello] => [hallo]
# [hello] => [sers]
# [hurry] => [beeil dich]
# [hurry] => [schnell]
# [i hid] => [ich versteckte mich]
# [i hid] => [ich habe mich versteckt]
# [i ran] => [ich rannte]
# [i see] => [ich verstehe]
# [i see] => [aha]
# [i try] => [ich versuche es]
# [i try] => [ich probiere es]
# [i won] => [ich hab gewonnen]
# [i won] => [ich habe gewonnen]
# [i won] => [ich habe gewonnen]
# [oh no] => [oh nein]
# [relax] => [entspann dich]
# [shoot] => [feuer]
# [shoot] => [schie]
# [smile] => [lacheln]
# [sorry] => [entschuldigung]
# [ask me] => [frag mich]
# [ask me] => [fragt mich]
# [ask me] => [fragen sie mich]
# [attack] => [angriff]
# [attack] => [attacke]
# [buy it] => [kaufs]
# [cheers] => [zum wohl]
# [eat it] => [iss es]
# [eat up] => [iss auf]
# [eat up] => [iss auf]
# [freeze] => [keine bewegung]
# [freeze] => [stehenbleiben]
# [go now] => [geh jetzt]
# [got it] => [verstanden]
# [got it] => [ich habs]
# [got it] => [aha]
# [got it] => [kapiert]
# [got it] => [verstanden]
# [got it] => [einverstanden]
# [he ran] => [er rannte]
# [he ran] => [er lief]
# [hop in] => [mach mit]
# [hop in] => [spring rein]
# [hug me] => [druck mich]
# [hug me] => [nimm mich in den arm]
# [hug me] => [umarme mich]
# [i care] => [mir ist es wichtig]
# [i fell] => [ich fiel]
# [i fell] => [ich fiel hin]
# [i fell] => [ich sturzte]
# [i fell] => [ich bin hingefallen]
# [i fell] => [ich bin gesturzt]
# [i fled] => [ich fluchtete]
# [i fled] => [ich bin gefluchtet]
# [i know] => [ich wei]
# [i lied] => [ich habe gelogen]
# [i lost] => [ich habe verloren]
# [i paid] => [ich habe bezahlt]
# [i paid] => [ich zahlte]
# [i sang] => [ich sang]
# [i spit] => [ich spuckte]
# [i spit] => [ich habe gespuckt]
# [i swim] => [ich schwimme]
# [i wept] => [ich weinte]
# [i wept] => [ich habe geweint]
# [im] => [ich bin jahre alt]
# [im] => [ich bin]
# [im ok] => [mir gehts gut]
# [im ok] => [es geht mir gut]
# [im up] => [ich bin wach]
# [im up] => [ich bin auf]
# [listen] => [hort zu]
# [no way] => [unmoglich]
# [no way] => [das kommt nicht in frage]
# [no way] => [das gibts doch nicht]
# [no way] => [ausgeschlossen]
# [no way] => [in keinster weise]
# [really] => [wirklich]
# [really] => [echt]
# [really] => [im ernst]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('/content/english-german.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[9000:]
# save
save_clean_data(dataset, '/content/english-german-both.pkl')
save_clean_data(train, '/content/english-german-train.pkl')
save_clean_data(test, '/content/english-german-test.pkl')
# Out:
# Saved: /content/english-german-both.pkl
# Saved: /content/english-german-train.pkl
# Saved: /content/english-german-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('/content/english-german-both.pkl')
train = load_clean_sentences('/content/english-german-train.pkl')
test = load_clean_sentences('/content/english-german-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('German Vocabulary Size: %d' % ger_vocab_size)
print('German Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = '/content/model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2185
# English Max Length: 5
# German Vocabulary Size: 3529
# German Max Length: 9
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 9, 256)            903424
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 5, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 2185)           561545
# =================================================================
# Total params: 2,515,593
# Trainable params: 2,515,593
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 34s - loss: 4.1026 - val_loss: 3.3438
#
# Epoch 00001: val_loss improved from inf to 3.34378, saving model to /content/model.h5
# Epoch 2/100
# 141/141 - 25s - loss: 3.2065 - val_loss: 3.2005
#
# Epoch 00002: val_loss improved from 3.34378 to 3.20046, saving model to /content/model.h5
# Epoch 3/100
# 141/141 - 25s - loss: 3.0681 - val_loss: 3.0970
#
# Epoch 00003: val_loss improved from 3.20046 to 3.09695, saving model to /content/model.h5
# Epoch 4/100
# 141/141 - 25s - loss: 2.9174 - val_loss: 2.9755
#
# Epoch 00004: val_loss improved from 3.09695 to 2.97547, saving model to /content/model.h5
# Epoch 5/100
# 141/141 - 25s - loss: 2.7707 - val_loss: 2.8678
#
# Epoch 00005: val_loss improved from 2.97547 to 2.86776, saving model to /content/model.h5
# Epoch 6/100
# 141/141 - 25s - loss: 2.6206 - val_loss: 2.7482
#
# Epoch 00006: val_loss improved from 2.86776 to 2.74823, saving model to /content/model.h5
# Epoch 7/100
# 141/141 - 25s - loss: 2.4660 - val_loss: 2.6427
#
# Epoch 00007: val_loss improved from 2.74823 to 2.64274, saving model to /content/model.h5
# Epoch 8/100
# 141/141 - 25s - loss: 2.3287 - val_loss: 2.5473
#
# Epoch 00008: val_loss improved from 2.64274 to 2.54734, saving model to /content/model.h5
# Epoch 9/100
# 141/141 - 25s - loss: 2.1896 - val_loss: 2.4549
#
# Epoch 00009: val_loss improved from 2.54734 to 2.45491, saving model to /content/model.h5
# Epoch 10/100
# 141/141 - 25s - loss: 2.0586 - val_loss: 2.3810
#
# Epoch 00010: val_loss improved from 2.45491 to 2.38102, saving model to /content/model.h5
# Epoch 11/100
# 141/141 - 25s - loss: 1.9326 - val_loss: 2.3022
#
# Epoch 00011: val_loss improved from 2.38102 to 2.30224, saving model to /content/model.h5
# Epoch 12/100
# 141/141 - 25s - loss: 1.8172 - val_loss: 2.2416
#
# Epoch 00012: val_loss improved from 2.30224 to 2.24164, saving model to /content/model.h5
# Epoch 13/100
# 141/141 - 25s - loss: 1.7068 - val_loss: 2.1946
#
# Epoch 00013: val_loss improved from 2.24164 to 2.19456, saving model to /content/model.h5
# Epoch 14/100
# 141/141 - 25s - loss: 1.6027 - val_loss: 2.1525
#
# Epoch 00014: val_loss improved from 2.19456 to 2.15255, saving model to /content/model.h5
# Epoch 15/100
# 141/141 - 25s - loss: 1.5041 - val_loss: 2.0970
#
# Epoch 00015: val_loss improved from 2.15255 to 2.09695, saving model to /content/model.h5
# Epoch 16/100
# 141/141 - 24s - loss: 1.4098 - val_loss: 2.0538
#
# Epoch 00016: val_loss improved from 2.09695 to 2.05383, saving model to /content/model.h5
# Epoch 17/100
# 141/141 - 25s - loss: 1.3166 - val_loss: 2.0025
#
# Epoch 00017: val_loss improved from 2.05383 to 2.00251, saving model to /content/model.h5
# Epoch 18/100
# 141/141 - 25s - loss: 1.2284 - val_loss: 1.9894
#
# Epoch 00018: val_loss improved from 2.00251 to 1.98939, saving model to /content/model.h5
# Epoch 19/100
# 141/141 - 25s - loss: 1.1454 - val_loss: 1.9455
#
# Epoch 00019: val_loss improved from 1.98939 to 1.94545, saving model to /content/model.h5
# Epoch 20/100
# 141/141 - 25s - loss: 1.0622 - val_loss: 1.9130
#
# Epoch 00020: val_loss improved from 1.94545 to 1.91302, saving model to /content/model.h5
# Epoch 21/100
# 141/141 - 25s - loss: 0.9826 - val_loss: 1.8846
#
# Epoch 00021: val_loss improved from 1.91302 to 1.88456, saving model to /content/model.h5
# Epoch 22/100
# 141/141 - 25s - loss: 0.9104 - val_loss: 1.8562
#
# Epoch 00022: val_loss improved from 1.88456 to 1.85619, saving model to /content/model.h5
# Epoch 23/100
# 141/141 - 25s - loss: 0.8373 - val_loss: 1.8366
#
# Epoch 00023: val_loss improved from 1.85619 to 1.83660, saving model to /content/model.h5
# Epoch 24/100
# 141/141 - 26s - loss: 0.7682 - val_loss: 1.8105
#
# Epoch 00024: val_loss improved from 1.83660 to 1.81046, saving model to /content/model.h5
# Epoch 25/100
# 141/141 - 26s - loss: 0.7021 - val_loss: 1.8091
#
# Epoch 00025: val_loss improved from 1.81046 to 1.80912, saving model to /content/model.h5
# Epoch 26/100
# 141/141 - 25s - loss: 0.6428 - val_loss: 1.7765
#
# Epoch 00026: val_loss improved from 1.80912 to 1.77651, saving model to /content/model.h5
# Epoch 27/100
# 141/141 - 25s - loss: 0.5875 - val_loss: 1.7808
#
# Epoch 00027: val_loss did not improve from 1.77651
# Epoch 28/100
# 141/141 - 25s - loss: 0.5368 - val_loss: 1.7521
#
# Epoch 00028: val_loss improved from 1.77651 to 1.75210, saving model to /content/model.h5
# Epoch 29/100
# 141/141 - 25s - loss: 0.4896 - val_loss: 1.7576
#
# Epoch 00029: val_loss did not improve from 1.75210
# Epoch 30/100
# 141/141 - 25s - loss: 0.4487 - val_loss: 1.7493
#
# Epoch 00030: val_loss improved from 1.75210 to 1.74926, saving model to /content/model.h5
# Epoch 31/100
# 141/141 - 25s - loss: 0.4123 - val_loss: 1.7449
#
# Epoch 00031: val_loss improved from 1.74926 to 1.74491, saving model to /content/model.h5
# Epoch 32/100
# 141/141 - 25s - loss: 0.3786 - val_loss: 1.7387
#
# Epoch 00032: val_loss improved from 1.74491 to 1.73875, saving model to /content/model.h5
# Epoch 33/100
# 141/141 - 25s - loss: 0.3462 - val_loss: 1.7618
#
# Epoch 00033: val_loss did not improve from 1.73875
# Epoch 34/100
# 141/141 - 25s - loss: 0.3182 - val_loss: 1.7455
#
# Epoch 00034: val_loss did not improve from 1.73875
# Epoch 35/100
# 141/141 - 25s - loss: 0.2934 - val_loss: 1.7571
#
# Epoch 00035: val_loss did not improve from 1.73875
# Epoch 36/100
# 141/141 - 25s - loss: 0.2731 - val_loss: 1.7510
#
# Epoch 00036: val_loss did not improve from 1.73875
# Epoch 37/100
# 141/141 - 25s - loss: 0.2515 - val_loss: 1.7486
#
# Epoch 00037: val_loss did not improve from 1.73875
# Epoch 38/100
# 141/141 - 26s - loss: 0.2339 - val_loss: 1.7492
#
# Epoch 00038: val_loss did not improve from 1.73875
# Epoch 39/100
# 141/141 - 25s - loss: 0.2182 - val_loss: 1.7722
#
# Epoch 00039: val_loss did not improve from 1.73875
# Epoch 40/100
# 141/141 - 25s - loss: 0.2039 - val_loss: 1.7642
#
# Epoch 00040: val_loss did not improve from 1.73875
# Epoch 41/100
# 141/141 - 25s - loss: 0.1922 - val_loss: 1.7728
#
# Epoch 00041: val_loss did not improve from 1.73875
# Epoch 42/100
# 141/141 - 25s - loss: 0.1814 - val_loss: 1.7824
#
# Epoch 00042: val_loss did not improve from 1.73875
# Epoch 43/100
# 141/141 - 25s - loss: 0.1714 - val_loss: 1.7969
#
# Epoch 00043: val_loss did not improve from 1.73875
# Epoch 44/100
# 141/141 - 25s - loss: 0.1621 - val_loss: 1.7881
#
# Epoch 00044: val_loss did not improve from 1.73875
# Epoch 45/100
# 141/141 - 25s - loss: 0.1552 - val_loss: 1.7870
#
# Epoch 00045: val_loss did not improve from 1.73875
# Epoch 46/100
# 141/141 - 25s - loss: 0.1460 - val_loss: 1.7982
#
# Epoch 00046: val_loss did not improve from 1.73875
# Epoch 47/100
# 141/141 - 25s - loss: 0.1395 - val_loss: 1.8100
#
# Epoch 00047: val_loss did not improve from 1.73875
# Epoch 48/100
# 141/141 - 25s - loss: 0.1354 - val_loss: 1.8185
#
# Epoch 00048: val_loss did not improve from 1.73875
# Epoch 49/100
# 141/141 - 25s - loss: 0.1315 - val_loss: 1.8195
#
# Epoch 00049: val_loss did not improve from 1.73875
# Epoch 50/100
# 141/141 - 25s - loss: 0.1271 - val_loss: 1.8313
#
# Epoch 00050: val_loss did not improve from 1.73875
# Epoch 51/100
# 141/141 - 25s - loss: 0.1222 - val_loss: 1.8462
#
# Epoch 00051: val_loss did not improve from 1.73875
# Epoch 52/100
# 141/141 - 25s - loss: 0.1196 - val_loss: 1.8466
#
# Epoch 00052: val_loss did not improve from 1.73875
# Epoch 53/100
# 141/141 - 25s - loss: 0.1152 - val_loss: 1.8464
#
# Epoch 00053: val_loss did not improve from 1.73875
# Epoch 54/100
# 141/141 - 25s - loss: 0.1127 - val_loss: 1.8510
#
# Epoch 00054: val_loss did not improve from 1.73875
# Epoch 55/100
# 141/141 - 25s - loss: 0.1102 - val_loss: 1.8697
#
# Epoch 00055: val_loss did not improve from 1.73875
# Epoch 56/100
# 141/141 - 25s - loss: 0.1073 - val_loss: 1.8651
#
# Epoch 00056: val_loss did not improve from 1.73875
# Epoch 57/100
# 141/141 - 25s - loss: 0.1055 - val_loss: 1.8640
#
# Epoch 00057: val_loss did not improve from 1.73875
# Epoch 58/100
# 141/141 - 25s - loss: 0.1048 - val_loss: 1.8809
#
# Epoch 00058: val_loss did not improve from 1.73875
# Epoch 59/100
# 141/141 - 25s - loss: 0.1035 - val_loss: 1.8793
#
# Epoch 00059: val_loss did not improve from 1.73875
# Epoch 60/100
# 141/141 - 25s - loss: 0.1004 - val_loss: 1.8869
#
# Epoch 00060: val_loss did not improve from 1.73875
# Epoch 61/100
# 141/141 - 25s - loss: 0.0986 - val_loss: 1.8954
#
# Epoch 00061: val_loss did not improve from 1.73875
# Epoch 62/100
# 141/141 - 25s - loss: 0.0963 - val_loss: 1.9074
#
# Epoch 00062: val_loss did not improve from 1.73875
# Epoch 63/100
# 141/141 - 25s - loss: 0.0958 - val_loss: 1.9017
#
# Epoch 00063: val_loss did not improve from 1.73875
# Epoch 64/100
# 141/141 - 25s - loss: 0.0949 - val_loss: 1.9119
#
# Epoch 00064: val_loss did not improve from 1.73875
# Epoch 65/100
# 141/141 - 25s - loss: 0.0934 - val_loss: 1.9265
#
# Epoch 00065: val_loss did not improve from 1.73875
# Epoch 66/100
# 141/141 - 25s - loss: 0.0931 - val_loss: 1.9207
#
# Epoch 00066: val_loss did not improve from 1.73875
# Epoch 67/100
# 141/141 - 25s - loss: 0.0910 - val_loss: 1.9328
#
# Epoch 00067: val_loss did not improve from 1.73875
# Epoch 68/100
# 141/141 - 25s - loss: 0.0901 - val_loss: 1.9560
#
# Epoch 00068: val_loss did not improve from 1.73875
# Epoch 69/100
# 141/141 - 25s - loss: 0.0894 - val_loss: 1.9289
#
# Epoch 00069: val_loss did not improve from 1.73875
# Epoch 70/100
# 141/141 - 25s - loss: 0.0882 - val_loss: 1.9481
#
# Epoch 00070: val_loss did not improve from 1.73875
# Epoch 71/100
# 141/141 - 25s - loss: 0.0888 - val_loss: 1.9452
#
# Epoch 00071: val_loss did not improve from 1.73875
# Epoch 72/100
# 141/141 - 25s - loss: 0.0895 - val_loss: 1.9540
#
# Epoch 00072: val_loss did not improve from 1.73875
# Epoch 73/100
# 141/141 - 25s - loss: 0.0878 - val_loss: 1.9539
#
# Epoch 00073: val_loss did not improve from 1.73875
# Epoch 74/100
# 141/141 - 25s - loss: 0.0888 - val_loss: 1.9731
#
# Epoch 00074: val_loss did not improve from 1.73875
# Epoch 75/100
# 141/141 - 25s - loss: 0.0888 - val_loss: 1.9682
#
# Epoch 00075: val_loss did not improve from 1.73875
# Epoch 76/100
# 141/141 - 26s - loss: 0.0874 - val_loss: 1.9570
#
# Epoch 00076: val_loss did not improve from 1.73875
# Epoch 77/100
# 141/141 - 26s - loss: 0.0851 - val_loss: 1.9829
#
# Epoch 00077: val_loss did not improve from 1.73875
# Epoch 78/100
# 141/141 - 27s - loss: 0.0828 - val_loss: 1.9737
#
# Epoch 00078: val_loss did not improve from 1.73875
# Epoch 79/100
# 141/141 - 31s - loss: 0.0833 - val_loss: 1.9674
#
# Epoch 00079: val_loss did not improve from 1.73875
# Epoch 80/100
# 141/141 - 31s - loss: 0.0815 - val_loss: 2.0078
#
# Epoch 00080: val_loss did not improve from 1.73875
# Epoch 81/100
# 141/141 - 32s - loss: 0.0808 - val_loss: 1.9876
#
# Epoch 00081: val_loss did not improve from 1.73875
# Epoch 82/100
# 141/141 - 27s - loss: 0.0820 - val_loss: 2.0152
#
# Epoch 00082: val_loss did not improve from 1.73875
# Epoch 83/100
# 141/141 - 26s - loss: 0.0809 - val_loss: 2.0080
#
# Epoch 00083: val_loss did not improve from 1.73875
# Epoch 84/100
# 141/141 - 25s - loss: 0.0817 - val_loss: 1.9884
#
# Epoch 00084: val_loss did not improve from 1.73875
# Epoch 85/100
# 141/141 - 25s - loss: 0.0826 - val_loss: 2.0107
#
# Epoch 00085: val_loss did not improve from 1.73875
# Epoch 86/100
# 141/141 - 26s - loss: 0.0852 - val_loss: 2.0316
#
# Epoch 00086: val_loss did not improve from 1.73875
# Epoch 87/100
# 141/141 - 26s - loss: 0.0845 - val_loss: 2.0082
#
# Epoch 00087: val_loss did not improve from 1.73875
# Epoch 88/100
# 141/141 - 26s - loss: 0.0828 - val_loss: 2.0192
#
# Epoch 00088: val_loss did not improve from 1.73875
# Epoch 89/100
# 141/141 - 25s - loss: 0.0812 - val_loss: 2.0364
#
# Epoch 00089: val_loss did not improve from 1.73875
# Epoch 90/100
# 141/141 - 25s - loss: 0.0798 - val_loss: 2.0215
#
# Epoch 00090: val_loss did not improve from 1.73875
# Epoch 91/100
# 141/141 - 25s - loss: 0.0781 - val_loss: 2.0419
#
# Epoch 00091: val_loss did not improve from 1.73875
# Epoch 92/100
# 141/141 - 25s - loss: 0.0768 - val_loss: 2.0251
#
# Epoch 00092: val_loss did not improve from 1.73875
# Epoch 93/100
# 141/141 - 26s - loss: 0.0775 - val_loss: 2.0443
#
# Epoch 00093: val_loss did not improve from 1.73875
# Epoch 94/100
# 141/141 - 25s - loss: 0.0768 - val_loss: 2.0541
#
# Epoch 00094: val_loss did not improve from 1.73875
# Epoch 95/100
# 141/141 - 25s - loss: 0.0757 - val_loss: 2.0451
#
# Epoch 00095: val_loss did not improve from 1.73875
# Epoch 96/100
# 141/141 - 25s - loss: 0.0763 - val_loss: 2.0434
#
# Epoch 00096: val_loss did not improve from 1.73875
# Epoch 97/100
# 141/141 - 25s - loss: 0.0765 - val_loss: 2.0412
#
# Epoch 00097: val_loss did not improve from 1.73875
# Epoch 98/100
# 141/141 - 25s - loss: 0.0763 - val_loss: 2.0444
#
# Epoch 00098: val_loss did not improve from 1.73875
# Epoch 99/100
# 141/141 - 25s - loss: 0.0765 - val_loss: 2.0797
#
# Epoch 00099: val_loss did not improve from 1.73875
# Epoch 100/100
# 141/141 - 25s - loss: 0.0772 - val_loss: 2.0870
#
# Epoch 00100: val_loss did not improve from 1.73875

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src, test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('/content/english-german-both.pkl')
train = load_clean_sentences('/content/english-german-train.pkl')
test = load_clean_sentences('/content/english-german-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('/content/model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[du bist lustig], target=[youre funny], predicted=[youre funny]
# src=[ich bin in perth], target=[im in perth], predicted=[im in trouble]
# src=[ich liebe ihn], target=[i love him], predicted=[i love him]
# src=[tom ist blod], target=[toms stupid], predicted=[toms is]
# src=[ich werde anwesend sein], target=[ill attend], predicted=[ill attend]
# src=[hey warte mal], target=[hey wait up], predicted=[hey wait up]
# src=[tom kniete sich hin], target=[tom knelt], predicted=[tom kneeled]
# src=[komm herein], target=[come inside], predicted=[come inside]
# src=[horen sie auf zu raufen], target=[stop fighting], predicted=[stop fighting]
# src=[es ist ihnen kalt], target=[theyre cold], predicted=[theyre cold]
# BLEU-1: 0.887445
# BLEU-2: 0.841620
# BLEU-3: 0.734426
# BLEU-4: 0.404090
# test
# src=[er hat gekundigt], target=[he quit], predicted=[he resigned]
# src=[ich mag schnee], target=[i like snow], predicted=[i like snow]
# src=[die rechnung bitte], target=[check please], predicted=[check please]
# src=[wie konnen sie es wagen], target=[how dare you], predicted=[how dare you]
# src=[er skatet], target=[he is skating], predicted=[he disappeared]
# src=[ich komme klar], target=[i can manage], predicted=[ill managing]
# src=[wir nehmen es], target=[well take it], predicted=[well do it]
# src=[bleibt ruhig], target=[stay cool], predicted=[keep calm]
# src=[tom ist klug], target=[tom is clever], predicted=[toms is]
# src=[ich bin kein poet], target=[im not a poet], predicted=[im not in]
# BLEU-1: 0.576243
# BLEU-2: 0.453467
# BLEU-3: 0.369980
# BLEU-4: 0.174124
